# %%
import pickle
import pandas as pd
from results_manager import results2table

# %%
results_neis = pickle.load(open("./results/results_NEIS2157.pkl", "rb")) 
results2table(results_neis)
# Out:
#                                rep   dnabert     prose alphafold
# combiner dimensional PCA
# pca      all              0.196920  0.062727  0.225986      None
#          default          0.142359  0.065709  0.254419      None
# average  all              0.196920  0.063429  0.231623      None
#          default          0.142359  0.018753  0.194449      None
# sum      all              0.196920  0.063429  0.231623      None
#          default          0.142359  0.018753  0.195133      None
# max      all              0.196920  0.060892  0.227712      None
#          default          0.142359  0.056290  0.207680      None

# %%
results_globins = pickle.load(open("./results/results_globins.pkl", "rb"))
results2table(results_globins)
# Out:
#                                rep   dnabert     prose  alphafold
# combiner dimensional PCA
# pca      all              0.583333 -0.020308  0.491667   0.700000
#          default          0.613095  0.247549  0.491667   0.700000
# average  all              0.583333 -0.040546  0.583333   0.313095
#          default          0.613095 -0.174475  0.583333   0.613095
# sum      all              0.583333  0.521429  0.791667   0.700000
#          default          0.613095  0.491667  0.791667   0.700000
# max      all              0.583333 -0.040546  0.583333   0.791667
#          default          0.613095 -0.093651  0.583333   1.000000

# %%
results_globins = pickle.load(open("./results/enrichment_results_proteins.pkl", "rb"))
results2table(results_globins)
# Out:
#                                rep   dnabert     prose  alphafold
# combiner dimensional PCA
# pca      all              0.027895  0.053848  0.360103   0.057204
#          default          0.030713  0.047105  0.363423   0.154251
# average  all              0.027895  0.053848  0.186395   0.140538
#          default          0.030713  0.047208  0.190775   0.223686
# sum      all              0.027895  0.053848  0.207862   0.079814
#          default          0.030713  0.047208  0.215603   0.172041
# max      all              0.027895  0.053848  0.173458   0.078680
#          default          0.030713  0.047208  0.170138   0.115562
