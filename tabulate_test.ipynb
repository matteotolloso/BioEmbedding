# %%
import pandas as pd
import numpy as np

iterables = [["max", "average", "sum", "pca"], ["default", "all"]]

index = pd.MultiIndex.from_product(iterables, names=["combiner", "PCA"])

df = pd.DataFrame([np.random.randn(3) for i in range(8)] , index=index, columns=["rep", "prose", "dnabert"])

df
# Out:
#                        rep     prose   dnabert
# combiner PCA
# max      default  0.245226 -0.235176  1.208817
#          all      0.311922 -0.356508  0.829456
# average  default -0.328282  1.473124  0.448558
#          all     -1.738427 -0.554569 -1.257909
# sum      default  0.022380  0.831230 -1.578104
#          all     -0.718366  0.100105  0.907652
# pca      default -0.040856 -0.537628  0.704527
#          all      0.071997 -0.722148 -0.653525

# %%
# Out:
# <style type="text/css">
# #T_27ad3 th.index_name {
#   font-weight: bold;
# }
# </style>
# <table id="T_27ad3">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27ad3_level0_col0" class="col_heading level0 col0" >rep</th>
#       <th id="T_27ad3_level0_col1" class="col_heading level0 col1" >prose</th>
#       <th id="T_27ad3_level0_col2" class="col_heading level0 col2" >dnabert</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >combiner</th>
#       <th class="index_name level1" >PCA</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27ad3_level0_row0" class="row_heading level0 row0" rowspan="2">max</th>
#       <th id="T_27ad3_level1_row0" class="row_heading level1 row0" >on</th>
# ...

# %%
# to latex file
with open("table.tex", "w") as f:
    f.write(df.to_latex())
# Out:
# /tmp/ipykernel_15507/4075360656.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   f.write(df.to_latex())
